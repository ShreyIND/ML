# %%
import pickle
import numpy as np

# %%
pipe=pickle.load(open('pipe.pkl','rb'))

# %%
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
pred=pipe.predict(test_input2)[0]
if pred==0:
    print('Not Survived')
else:
    print('Survived')
# Out:
# Not Survived
# C:\Users\shrey\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\shrey\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
